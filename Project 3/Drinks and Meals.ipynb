# %% [markdown]
# # Drinks and Meals

# %%
import pandas as pd
import requests
import json
import matplotlib
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %matplotlib inline

# %%
#https://www.thecocktaildb.com/api.php
#https://www.themealdb.com/api.php

# %%
url = "https://www.thecocktaildb.com/api/json/v1/1/search.php?s=kami"

# %%
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{"drinks":[{"idDrink":"11600","strDrink":"Kamikaze","strDrinkAlternate":null,"strDrinkES":null,"strDrinkDE":null,"strDrinkFR":null,"strDrinkZH-HANS":null,"strDrinkZH-HANT":null,"strTags":"IBA,NewEra","strVideo":null,"strCategory":"Ordinary Drink","strIBA":"New Era Drinks","strAlcoholic":"Alcoholic","strGlass":"Cocktail glass","strInstructions":"Shake all ingredients together with ice. Strain into glass, garnish and serve.","strInstructionsES":null,"strInstructionsDE":"Alle Zutaten zusammen mit Eis sch\\u00fctteln. In ein Glas abseihen, garnieren und servieren.","strInstructionsFR":null,"strInstructionsZH-HANS":null,"strInstructionsZH-HANT":null,"strDrinkThumb":"https:\\/\\/www.thecocktaildb.com\\/images\\/media\\/drink\\/xa58bb1504373204.jpg","strIngredient1":"Vodka","strIngredient2":"Triple sec","strIngredient3":"Lime juice","strIngredient4":null,"strIngredient5":null,"strIngredient6":null,"strIngredient7":null,"strIngredient8":null,"strIngredient9":null,"strIngredient10":null,"str
# ...

# %%
r.json()
# Out:
# {'drinks': [{'idDrink': '11600',
#    'strDrink': 'Kamikaze',
#    'strDrinkAlternate': None,
#    'strDrinkES': None,
#    'strDrinkDE': None,
#    'strDrinkFR': None,
#    'strDrinkZH-HANS': None,
#    'strDrinkZH-HANT': None,
#    'strTags': 'IBA,NewEra',
#    'strVideo': None,
#    'strCategory': 'Ordinary Drink',
#    'strIBA': 'New Era Drinks',
#    'strAlcoholic': 'Alcoholic',
#    'strGlass': 'Cocktail glass',
#    'strInstructions': 'Shake all ingredients together with ice. Strain into glass, garnish and serve.',
#    'strInstructionsES': None,
#    'strInstructionsDE': 'Alle Zutaten zusammen mit Eis schütteln. In ein Glas abseihen, garnieren und servieren.',
#    'strInstructionsFR': None,
#    'strInstructionsZH-HANS': None,
#    'strInstructionsZH-HANT': None,
#    'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/xa58bb1504373204.jpg',
#    'strIngredient1': 'Vodka',
#    'strIngredient2': 'Triple sec',
#    'strIngredient3': 'Lime juice',
# ...

# %%
r.json().keys()
# Out:
# dict_keys(['drinks'])

# %%
r.json()["drinks"]
# Out:
# [{'idDrink': '11600',
#   'strDrink': 'Kamikaze',
#   'strDrinkAlternate': None,
#   'strDrinkES': None,
#   'strDrinkDE': None,
#   'strDrinkFR': None,
#   'strDrinkZH-HANS': None,
#   'strDrinkZH-HANT': None,
#   'strTags': 'IBA,NewEra',
#   'strVideo': None,
#   'strCategory': 'Ordinary Drink',
#   'strIBA': 'New Era Drinks',
#   'strAlcoholic': 'Alcoholic',
#   'strGlass': 'Cocktail glass',
#   'strInstructions': 'Shake all ingredients together with ice. Strain into glass, garnish and serve.',
#   'strInstructionsES': None,
#   'strInstructionsDE': 'Alle Zutaten zusammen mit Eis schütteln. In ein Glas abseihen, garnieren und servieren.',
#   'strInstructionsFR': None,
#   'strInstructionsZH-HANS': None,
#   'strInstructionsZH-HANT': None,
#   'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/xa58bb1504373204.jpg',
#   'strIngredient1': 'Vodka',
#   'strIngredient2': 'Triple sec',
#   'strIngredient3': 'Lime juice',
#   'strIngredient4': None,
# ...

# %%
df = pd.DataFrame(r.json()["drinks"])

# %%
df.dropna(axis='columns', how='all')
# Out:
#   idDrink  strDrink     strTags     strCategory          strIBA strAlcoholic  \
# 0   11600  Kamikaze  IBA,NewEra  Ordinary Drink  New Era Drinks    Alcoholic
#
#          strGlass                                    strInstructions  \
# 0  Cocktail glass  Shake all ingredients together with ice. Strai...
#
#                                    strInstructionsDE  \
# 0  Alle Zutaten zusammen mit Eis schütteln. In ei...
#
#                                        strDrinkThumb strIngredient1  \
# 0  https://www.thecocktaildb.com/images/media/dri...          Vodka
#
#   strIngredient2 strIngredient3 strMeasure1 strMeasure2 strMeasure3  \
# 0     Triple sec     Lime juice       1 oz        1 oz        1 oz
#
#   strCreativeCommonsConfirmed         dateModified
# 0                          No  2017-09-02 18:26:44

# %% [markdown]
# ## Recepies

# %%
url_r = "https://www.themealdb.com/api/json/v1/1/search.php?s=Arrabiata"

# %%
rc = requests.get(url_r)

# %%
rc
# Out:
# <Response [200]>

# %%
rc.json()
# Out:
# {'meals': [{'idMeal': '52771',
#    'strMeal': 'Spicy Arrabiata Penne',
#    'strDrinkAlternate': None,
#    'strCategory': 'Vegetarian',
#    'strArea': 'Italian',
#    'strInstructions': 'Bring a large pot of water to a boil. Add kosher salt to the boiling water, then add the pasta. Cook according to the package instructions, about 9 minutes.\r\nIn a large skillet over medium-high heat, add the olive oil and heat until the oil starts to shimmer. Add the garlic and cook, stirring, until fragrant, 1 to 2 minutes. Add the chopped tomatoes, red chile flakes, Italian seasoning and salt and pepper to taste. Bring to a boil and cook for 5 minutes. Remove from the heat and add the chopped basil.\r\nDrain the pasta and add it to the sauce. Garnish with Parmigiano-Reggiano flakes and more basil and serve warm.',
#    'strMealThumb': 'https://www.themealdb.com/images/media/meals/ustsqw1468250014.jpg',
#    'strTags': 'Pasta,Curry',
# ...

# %%
rc.json().keys()
# Out:
# dict_keys(['meals'])

# %%
rc.json()["meals"]
# Out:
# [{'idMeal': '52771',
#   'strMeal': 'Spicy Arrabiata Penne',
#   'strDrinkAlternate': None,
#   'strCategory': 'Vegetarian',
#   'strArea': 'Italian',
#   'strInstructions': 'Bring a large pot of water to a boil. Add kosher salt to the boiling water, then add the pasta. Cook according to the package instructions, about 9 minutes.\r\nIn a large skillet over medium-high heat, add the olive oil and heat until the oil starts to shimmer. Add the garlic and cook, stirring, until fragrant, 1 to 2 minutes. Add the chopped tomatoes, red chile flakes, Italian seasoning and salt and pepper to taste. Bring to a boil and cook for 5 minutes. Remove from the heat and add the chopped basil.\r\nDrain the pasta and add it to the sauce. Garnish with Parmigiano-Reggiano flakes and more basil and serve warm.',
#   'strMealThumb': 'https://www.themealdb.com/images/media/meals/ustsqw1468250014.jpg',
#   'strTags': 'Pasta,Curry',
#   'strYoutube': 'https://www.youtube.com/watch?v=1IszT_guI08',
# ...

# %%
dfc = pd.DataFrame(rc.json()["meals"])

# %%
dfc.dropna(axis='columns', how='all')
# Out:
#   idMeal                strMeal strCategory  strArea  \
# 0  52771  Spicy Arrabiata Penne  Vegetarian  Italian
#
#                                      strInstructions  \
# 0  Bring a large pot of water to a boil. Add kosh...
#
#                                         strMealThumb      strTags  \
# 0  https://www.themealdb.com/images/media/meals/u...  Pasta,Curry
#
#                                     strYoutube strIngredient1 strIngredient2  \
# 0  https://www.youtube.com/watch?v=1IszT_guI08   penne rigate      olive oil
#
#   strIngredient3    strIngredient4    strIngredient5     strIngredient6  \
# 0         garlic  chopped tomatoes  red chile flakes  italian seasoning
#
#   strIngredient7       strIngredient8 strIngredient9 strIngredient10  \
# 0          basil  Parmigiano-Reggiano
#
#   strIngredient11 strIngredient12 strIngredient13 strIngredient14  \
# 0
#
#   strIngredient15 strMeasure1 strMeasure2 strMeasure3 strMeasure4  \
# ...

# %%
def drink(name):
    url = f"https://www.thecocktaildb.com/api/json/v1/1/search.php?s={str(name)}"
    r = requests.get(url)
    df = pd.DataFrame(r.json()["drinks"])
    return df.dropna(axis='columns', how='all')

def meal(name):
    url = f"https://www.themealdb.com/api/json/v1/1/search.php?s={str(name)}"
    r = requests.get(url)
    df = pd.DataFrame(r.json()["meals"])
    return df.dropna(axis='columns', how='all')

# %%
drink("margarita")
# Out:
#   idDrink              strDrink                  strTags     strCategory  \
# 0   11007             Margarita  IBA,ContemporaryClassic  Ordinary Drink
# 1   11118        Blue Margarita                     None  Ordinary Drink
# 2   17216     Tommy's Margarita               IBA,NewEra  Ordinary Drink
# 3   16158    Whitecap Margarita                     None   Other/Unknown
# 4   12322  Strawberry Margarita                     None  Ordinary Drink
#
#                   strIBA strAlcoholic                  strGlass  \
# 0  Contemporary Classics    Alcoholic            Cocktail glass
# 1                   None    Alcoholic            Cocktail glass
# 2         New Era Drinks    Alcoholic       Old-Fashioned glass
# 3                   None    Alcoholic  Margarita/Coupette glass
# 4                   None    Alcoholic            Cocktail glass
#
#                                      strInstructions  \
# 0  Rub the rim of the glass with the lime slice t...
# ...

# %%
meal("lasa")
# Out:
#   idMeal             strMeal strCategory   strArea  \
# 0  52844             Lasagne       Pasta   Italian
# 1  52775       Vegan Lasagna       Vegan   Italian
# 2  52987  Lasagna Sandwiches       Pasta  American
#
#                                      strInstructions  \
# 0  Heat the oil in a large saucepan. Use kitchen ...
# 1  1) Preheat oven to 180 degrees celcius. \r\n2)...
# 2  1. In a small bowl, combine the first four ing...
#
#                                         strMealThumb      strTags  \
# 0  https://www.themealdb.com/images/media/meals/w...         None
# 1  https://www.themealdb.com/images/media/meals/r...  Vegan,Pasta
# 2  https://www.themealdb.com/images/media/meals/x...     Sandwich
#
#                                     strYoutube     strIngredient1  \
# 0  https://www.youtube.com/watch?v=gfhfsBPt46s          Olive Oil
# 1  https://www.youtube.com/watch?v=VU8cXvlGbvc  green red lentils
# 2                                                      Sour Cream
#
# ...

# %% [markdown]
# ## Movies

# %%
#url = "https://api.themoviedb.org/3/movie/550?api_key=17e3a1cd0a989af2da250c134b4a3cd9"
#url = "https://api.themoviedb.org/3/find/tt7131622?api_key=17e3a1cd0a989af2da250c134b4a3cd9&external_source=imdb_id"
url ="https://api.themoviedb.org/3/search/company?api_key=17e3a1cd0a989af2da250c134b4a3cd9&query="

# %%
rm = requests.get(url)

# %%
rm
# Out:
# <Response [404]>

# %%
rm.json()
# Out:
# {'status_code': 34,
#  'status_message': 'The resource you requested could not be found.'}

# %%
rm.json().keys()
# Out:
# dict_keys(['status_code', 'status_message'])

# %%
#df =pd.DataFrame([rm.json()["original_title"],rm.json()["budget"],rm.json()["id"],rm.json()["original_language"],rm.json()["revenue"],rm.json()["runtime"],rm.json()["vote_average"]])
#df = pd.DataFrame(rm.json()['page'])
rm.json()['total_results']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-a3a6a22f3275> in <module>
#       1 #df =pd.DataFrame([rm.json()["original_title"],rm.json()["budget"],rm.json()["id"],rm.json()["original_language"],rm.json()["revenue"],rm.json()["runtime"],rm.json()["vote_average"]])
#       2 #df = pd.DataFrame(rm.json()['page'])
# ----> 3 rm.json()['total_results']
#
# KeyError: 'total_results'

# %%
#index =["original_title","budget","id","original_language","revenue","runtime","vote_average"]

# %%
#df = df.transpose()

# %%
#df.columns = index

# %%
df
# Out:
#   idDrink  strDrink strDrinkAlternate strDrinkES strDrinkDE strDrinkFR  \
# 0   11600  Kamikaze              None       None       None       None
#
#   strDrinkZH-HANS strDrinkZH-HANT     strTags strVideo     strCategory  \
# 0            None            None  IBA,NewEra     None  Ordinary Drink
#
#            strIBA strAlcoholic        strGlass  \
# 0  New Era Drinks    Alcoholic  Cocktail glass
#
#                                      strInstructions strInstructionsES  \
# 0  Shake all ingredients together with ice. Strai...              None
#
#                                    strInstructionsDE strInstructionsFR  \
# 0  Alle Zutaten zusammen mit Eis schütteln. In ei...              None
#
#   strInstructionsZH-HANS strInstructionsZH-HANT  \
# 0                   None                   None
#
#                                        strDrinkThumb strIngredient1  \
# 0  https://www.thecocktaildb.com/images/media/dri...          Vodka
#
# ...
