# %%
# define rooms and items


couch = {
    "name": "couch",
    "type": "furniture",
}

door_a = {
    "name": "door a",
    "type": "door",
}

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

piano = {
    "name": "piano",
    "type": "furniture",
}

game_room = {
    "name": "game room",
    "type": "room",
}

queen_bed = {
    "name": "queen bed",
    "type": "furniture",
}

door_b = {                       
    "name": "door b",
    "type": "door",
}

door_c = {                    
    "name": "door c",
    "type": "door",
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}

bedroom_1 = {
    "name": "bedroom 1",
    "type": "room",
}

dresser = {
    "name": "dresser",
    "type": "furniture",
}

double_bed = {
    "name": "double bed",
    "type": "furniture",
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}

door_d = {                       
    "name": "door d",
    "type": "door",
}

key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
}

bedroom_2 = {
    "name": "bedroom 2",
    "type": "room",
}

dinning_table = {
    "name": "dining table",
    "type": "furniture",
}


living_room = {
    "name": "living room",
    "type": "room",
}

outside = {
  "name": "outside"
}

all_rooms = [game_room, bedroom_1, bedroom_2, living_room, outside]

all_doors = [door_a, door_b, door_c, door_d]               

# define which items/rooms are related

object_relations = {
    "game room": [couch, piano, door_a],
    "piano": [key_a],
    "door a": [game_room, bedroom_1],
    "bedroom 1": [queen_bed, door_a, door_b, door_c], 
    "queen bed": [key_b],
    "door b": [bedroom_1, bedroom_2], 
    "bedroom 2": [double_bed, dresser, door_b],
    "door c": [bedroom_1, living_room],
    "dresser": [key_d],
    "double bed": [key_c],
    "living room": [dinning_table, door_c, door_d],
    "door d": [living_room, outside]    
}

# define game state. Do not directly change this dict. 
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This 
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}

def key_print(x):

    key = f"""
     ,o.          8 8
    d   bzzzzzzzza8o8b {x}
     `o'
            
            """
    return (key)

def door_print(x):
    
    door =f"""      
     /|
    / |
   /__|______
  |  __  __  |
  | |  ||  | | 
  | |__||__| |--- {x}
  |  __  __()|\  
  | |  ||  | |
  | |  ||  | |
  | |__||__| |
  |__________|
  """
    return (door)

def element_print(x):
    
    if x == "couch":
        return(f'''
 .-="""""""""""=-.
 | . . . . . . . |
 | .'.'.'.'.'.'. |  couch
()_______________()
||_______________||
 W               W
        ''')
    if x == "piano":
        return("""
        
    /
   /_\_\. o
  |_____L_/)  piano
   |   |  /Y
  ~~~~~~~~~~~  
        """)
    
    if x == "door a":
        return(door_print(x))
    if x == "queen bed":
        return(f"""
            ___
        ,-""___""-.
       .;""'| |`"":.
       || | | | | ||
       ||_|_|_|_|_||
      //          /|
     /__         //| queen bed
 ,-""___""-.    //||
.;""'| |`"":.  //
||/| | | | || //
||_|_|_|_|_||//
||_________||/
||         ||
''         ''
            """)
    if x == "door b":
        return(door_print(x))
    
    if x == "door c":
        return(door_print(x))
    
    if x == "double bed":
        return (f"""
   ||
   ||                   ||
||/||___                ||
|| /`   )____________||_/|
||/___ //_/_/_/_/_/_/||/ |
||(___)/_/_/_/_/_/_/_||  | double bed
||     |_|_|_|_|_|_|_|| /|
||     | | | | | | | ||/||
||~~~~~~~~~~~~~~~~~~~||
||                   ||  

""")
    
    if x == "dresser":
        return(f"""
        
 ____________________
|  o  | ,----------, |
|_____| |_===___O__| | dresser
|  o  | | ... ### .| |   
|_____|_|_O__ooo___|_|   
 (_)              (_)
        
        """)
    if x == "dining table":
        return("""
        
      ___--________________
     /  |[]|              /|
    /   '__'             / |
   /____________________/ / 
  |_____________________|/| dining table
   || ||              || ||
   || ||              || ||
   || ||              || ||
   ||                 || 
   ||                 ||
        
        """)
    
    if x == "door d":
        return(door_print(x))
    
    else:
        pass

oxygen = 12 
bold_start = '\033[1m'
bold_end   = '\033[0m'

class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

    
def linebreak():
    """
    Print a line break
    """
    print("\n\n")
    

def start_game():
    """
    Start the game
    """
    print(f"""{bcolors.WARNING}
 __     __     ______     __         ______     ______     __    __     ______       
/\ \  _ \ \   /\  ___\   /\ \       /\  ___\   /\  __ \   /\ "-./  \   /\  ___\      
\ \ \/ ".\ \  \ \  __\   \ \ \____  \ \ \____  \ \ \/\ \  \ \ \-./\ \  \ \  __\      
 \ \__/".~\_\  \ \_____\  \ \_____\  \ \_____\  \ \_____\  \ \_\ \ \_\  \ \_____\    
  \/_/   \/_/   \/_____/   \/_____/   \/_____/   \/_____/   \/_/  \/_/   \/_____/    {bcolors.ENDC}
                     {bcolors.OKGREEN}                                                                
                                 ______   ______                  
                                /\__  _\ /\  __ \                 
                                \/_/\ \/ \ \ \/\ \                
                                   \ \_\  \ \_____\             
                                    \/_/   \/_____/  {bcolors.ENDC}               
{bcolors.OKBLUE}                                                                                    
 ______   __  __     ______        ______     ______     __    __     ______         
/\__  _\ /\ \_\ \   /\  ___\      /\  ___\   /\  __ \   /\ "-./  \   /\  ___\        
\/_/\ \/ \ \  __ \  \ \  __\      \ \ \__ \  \ \  __ \  \ \ \-./\ \  \ \  __\        
   \ \_\  \ \_\ \_\  \ \_____\     \ \_____\  \ \_\ \_\  \ \_\ \ \_\  \ \_____\      
    \/_/   \/_/\/_/   \/_____/      \/_____/   \/_/\/_/   \/_/  \/_/   \/_____/   {bcolors.ENDC}   
                                                                                     
""")
    print(f"""You wake up on a couch and find yourself in a strange house with no windows which you have never been to before.\nYou don't remember why you are here and what had happened before. You found a note which says you are being watch and that each time you examine an object the oxygen level will decrease by 1, you start with the level of oxygen full at 12.\nYou feel some unknown danger is approaching and you must get out of the house,\n 
{bcolors.BOLD}
 /$$   /$$  /$$$$$$  /$$      /$$ /$$ /$$ /$$
| $$$ | $$ /$$__  $$| $$  /$ | $$| $$| $$| $$
| $$$$| $$| $$  \ $$| $$ /$$$| $$| $$| $$| $$
| $$ $$ $$| $$  | $$| $$/$$ $$ $$| $$| $$| $$
| $$  $$$$| $$  | $$| $$$$_  $$$$|__/|__/|__/
| $$\  $$$| $$  | $$| $$$/ \  $$$            
| $$ \  $$|  $$$$$$/| $$/   \  $$ /$$ /$$ /$$
|__/  \__/ \______/ |__/     \__/|__/|__/|__/ {bcolors.ENDC}
                                                                            
""")
    play_room(game_state["current_room"])

def play_room(room):
    """
    Play a room. First check if the room being played is the target room.
    If it is, the game will end with success. Otherwise, let player either 
    explore (list all items in this room) or examine an item found here.
    """
    game_state["current_room"] = room
    if(game_state["current_room"] == game_state["target_room"]):
        print(f"""Congrats! You escaped the room!\n""")
    elif oxygen == 0:
        print("\nYou ran out of OXYGEN!") 
    else:
        print("You are now in " + bcolors.WARNING + bold_start +room["name"].upper() + bold_end + bcolors.ENDC + " and you got " + bcolors.BOLD + str(oxygen) + " oxygen" + bcolors.ENDC + " left\n")
        print(bcolors.BOLD + bcolors.OKGREEN + "What would you like to do?\n\n"+ bcolors.ENDC + bcolors.ENDC)
        intended_action = input("Type 'explore' or 'examine'").strip().lower()
        if intended_action == "explore":
            explore_room(room)
            play_room(room)
        elif intended_action == "examine":
            examine_item(input(bcolors.BOLD + bcolors.OKGREEN + "\nWhat would you like to examine?\n\n" + bcolors.ENDC + bcolors.ENDC).strip().lower())
        else:
            print("Not sure what you mean. Type 'explore' or 'examine'.\n\n")
            play_room(room)
        linebreak()

def explore_room(room):
    """
    Explore a room. List all items belonging to this room.
    """
    items = [element_print(i["name"]) for i in object_relations[room["name"]]]
    print("\nYou explore the room. This is " + bcolors.WARNING + bold_start + room["name"].upper() + bold_end + bcolors.ENDC +  ". You find \n" + "\n ".join(items))

def get_next_room_of_door(door, current_room):
    """
    From object_relations, find the two rooms connected to the given door.
    Return the room that is not the current_room.
    """
    connected_rooms = object_relations[door["name"]]
    for room in connected_rooms:
        if(not current_room == room):
            return room

def examine_item(item_name):
    """
    Examine an item which can be a door or furniture.
    First make sure the intended item belongs to the current room.
    Then check if the item is a door. Tell player if key hasn't been 
    collected yet. Otherwise ask player if they want to go to the next
    room. If the item is not a door, then check if it contains keys.
    Collect the key if found and update the game state. At the end,
    play either the current or the next room depending on the game state
    to keep playing.
    """
    global oxygen
    current_room = game_state["current_room"]
    next_room = ""
    output = None
    
    for item in object_relations[current_room["name"]]:
        if(item["name"] == item_name):
            output = "\nYou examine " + bcolors.OKBLUE + item_name.upper() + bcolors.ENDC + ". " + "\n\n"
            oxygen -= 1
            if(item["type"] == "door"):
                have_key = False
                for key in game_state["keys_collected"]:
                    if(key["target"] == item):
                        have_key = True
                if(have_key):
                    output += "You unlock it with a key you have.\n\n"
                    next_room = get_next_room_of_door(item, current_room)
                else:
                    output += "It is locked but you don't have the key.\n\n"
            else:
                if(item["name"] in object_relations and len(object_relations[item["name"]])>0):
                    item_found = object_relations[item["name"]].pop()
                    game_state["keys_collected"].append(item_found)
                    output += "You find the" + "\n" + bcolors.OKBLUE + str(key_print(item_found["name"]).upper() + bcolors.ENDC)
                else:
                    output += """There isn't anything interesting about it.\n
¯\_(ツ)_/¯\n"""
            print(output)
            break

    if(output is None):
        print("The item you requested is not found in the current room.")
    
    if(next_room and input(bcolors.BOLD + bcolors.OKGREEN + "Do you want to go to the next room?\n" + bcolors.ENDC + bcolors.ENDC +  "\nEnter 'yes' or 'no'\n").strip().lower() == 'yes'):
        play_room(next_room)
    else:
        play_room(current_room)

# %%
game_state = INIT_GAME_STATE.copy()

start_game()
# Out:
#  __     __     ______     __         ______     ______     __    __     ______
# /\ \  _ \ \   /\  ___\   /\ \       /\  ___\   /\  __ \   /\ "-./  \   /\  ___\
# \ \ \/ ".\ \  \ \  __\   \ \ \____  \ \ \____  \ \ \/\ \  \ \ \-./\ \  \ \  __\
#  \ \__/".~\_\  \ \_____\  \ \_____\  \ \_____\  \ \_____\  \ \_\ \ \_\  \ \_____\
#   \/_/   \/_/   \/_____/   \/_____/   \/_____/   \/_____/   \/_/  \/_/   \/_____/
#
#                                  ______   ______
#                                 /\__  _\ /\  __ \
#                                 \/_/\ \/ \ \ \/\ \
#                                    \ \_\  \ \_____\
#                                     \/_/   \/_____/
#
#  ______   __  __     ______        ______     ______     __    __     ______
# /\__  _\ /\ \_\ \   /\  ___\      /\  ___\   /\  __ \   /\ "-./  \   /\  ___\
# \/_/\ \/ \ \  __ \  \ \  __\      \ \ \__ \  \ \  __ \  \ \ \-./\ \  \ \  __\
# ...
